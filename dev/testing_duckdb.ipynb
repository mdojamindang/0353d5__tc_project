# %%
import duckdb

# %%
import pandas as pd 
import numpy as np

# %%
import os
from dotenv import load_dotenv

# %%
df = pd.read_csv("../data/data.csv")

# %%
TEMP = os.getenv("DATA_PATH")

# %%
print(TEMP)
# Out:
# None

# %%
df
# Out:
#                                  restaurant_names food_names first_name  \
# 0       the-restaurant-at-the-end-of-the-universe     grains     Robert
# 1                            the-ice-cream-parlor      pasta  Alexandra
# 2                            johnnys-cashew-stand    cookies        Amy
# 3                            the-ice-cream-parlor      sugar    Michele
# 4                            johnnys-cashew-stand  ice cream       Ryan
# ...                                           ...        ...        ...
# 149995                           bean-juice-stand     yogurt   Nicholas
# 149996                       johnnys-cashew-stand      candy     Latoya
# 149997                       the-ice-cream-parlor    cookies      Isaac
# 149998  the-restaurant-at-the-end-of-the-universe      chips       Luke
# 149999                       the-ice-cream-parlor      honey   Jennifer
#
#         food_cost
# 0             1.0
# 1             1.0
# 2             4.0
# 3             1.0
# 4             7.0
# ...           ...
# 149995        7.5
# 149996        4.0
# 149997        8.5
# 149998        9.0
# 149999        6.0
#
# [150000 rows x 4 columns]

# %%
con = duckdb.connect("../database/data.duckdb")

# %%
con.execute("CREATE OR REPLACE TABLE TABLE_CHECK_DATA AS SELECT * FROM df")

# %%
con.execute("DROP TABLE TABLE_CHECK")

# %%
con.execute("SHOW TABLES").fetchall()
# Out:
# [('TABLE_CHECK_DATA',)]

# %%
df_x = con.sql("select * from TABLE_CHECK_DATA").df()

# %%
df_x
# Out:
#                                  restaurant_names food_names first_name  \
# 0       the-restaurant-at-the-end-of-the-universe     grains     Robert
# 1                            the-ice-cream-parlor      pasta  Alexandra
# 2                            johnnys-cashew-stand    cookies        Amy
# 3                            the-ice-cream-parlor      sugar    Michele
# 4                            johnnys-cashew-stand  ice cream       Ryan
# ...                                           ...        ...        ...
# 149995                           bean-juice-stand     yogurt   Nicholas
# 149996                       johnnys-cashew-stand      candy     Latoya
# 149997                       the-ice-cream-parlor    cookies      Isaac
# 149998  the-restaurant-at-the-end-of-the-universe      chips       Luke
# 149999                       the-ice-cream-parlor      honey   Jennifer
#
#         food_cost
# 0             1.0
# 1             1.0
# 2             4.0
# 3             1.0
# 4             7.0
# ...           ...
# 149995        7.5
# 149996        4.0
# 149997        8.5
# 149998        9.0
# 149999        6.0
#
# [150000 rows x 4 columns]

# %%
con.close()
